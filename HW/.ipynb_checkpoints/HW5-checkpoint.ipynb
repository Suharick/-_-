# %% [markdown]
# ## Линейные модели для регрессии

# %% [markdown]
# <p>Файл CSV включает почасовую/ежедневную сводку для Szeged, Венгрия, в период с 2006 по 2016 год.</p>
#
# <p>Данные, доступные в почасовом ответе:</p>
#
# - форматированная дата
# - облачно/ясно/...
# - осадки
# - температура
# - ощущение температуры
# - влажность
# - скорость ветра
# - подшипник ветра (градусы)
# - видимость (км)
# - громкая обложка
# - давление

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score

# %%
filename = 'weatherHistory.csv'
df = pd.read_csv(filename, index_col='Formatted Date') 
df.head()
# Out:
#                                      Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#                                Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200                  7.388889      0.89
# 2006-04-01 01:00:00.000 +0200                  7.227778      0.86
# 2006-04-01 02:00:00.000 +0200                  9.377778      0.89
# 2006-04-01 03:00:00.000 +0200                  5.944444      0.83
# 2006-04-01 04:00:00.000 +0200                  6.977778      0.83
#
#                                Wind Speed (km/h)  Wind Bearing (degrees)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200            14.1197                   251.0
# 2006-04-01 01:00:00.000 +0200            14.2646                   259.0
# 2006-04-01 02:00:00.000 +0200             3.9284                   204.0
# 2006-04-01 03:00:00.000 +0200            14.1036                   269.0
# 2006-04-01 04:00:00.000 +0200            11.0446                   259.0
#
#                                Visibility (km)  Loud Cover  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200          15.8263         0.0
# 2006-04-01 01:00:00.000 +0200          15.8263         0.0
# 2006-04-01 02:00:00.000 +0200          14.9569         0.0
# 2006-04-01 03:00:00.000 +0200          15.8263         0.0
# 2006-04-01 04:00:00.000 +0200          15.8263         0.0
#
#                                Pressure (millibars)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200               1015.13
# 2006-04-01 01:00:00.000 +0200               1015.63
# 2006-04-01 02:00:00.000 +0200               1015.94
# 2006-04-01 03:00:00.000 +0200               1016.41
# 2006-04-01 04:00:00.000 +0200               1016.51
#
#                                                    Daily Summary
# Formatted Date
# 2006-04-01 00:00:00.000 +0200  Partly cloudy throughout the day.
# 2006-04-01 01:00:00.000 +0200  Partly cloudy throughout the day.
# 2006-04-01 02:00:00.000 +0200  Partly cloudy throughout the day.
# 2006-04-01 03:00:00.000 +0200  Partly cloudy throughout the day.
# 2006-04-01 04:00:00.000 +0200  Partly cloudy throughout the day.

# %% [markdown]
# Некоторые данные представлены в строковом формате, но их можно проклассифицировать:

# %% [markdown]
# Рассмотрим данные второго столбца и соберем все отличающиеся классификации

# %%
summary_values = []
for i in df['Summary']:
    if not i in summary_values:
        summary_values.append(i)

# %%
summary_values.sort()
summary_values
# Out:
# ['Breezy',
#  'Breezy and Dry',
#  'Breezy and Foggy',
#  'Breezy and Mostly Cloudy',
#  'Breezy and Overcast',
#  'Breezy and Partly Cloudy',
#  'Clear',
#  'Dangerously Windy and Partly Cloudy',
#  'Drizzle',
#  'Dry',
#  'Dry and Mostly Cloudy',
#  'Dry and Partly Cloudy',
#  'Foggy',
#  'Humid and Mostly Cloudy',
#  'Humid and Overcast',
#  'Humid and Partly Cloudy',
#  'Light Rain',
#  'Mostly Cloudy',
#  'Overcast',
#  'Partly Cloudy',
#  'Rain',
#  'Windy',
#  'Windy and Dry',
#  'Windy and Foggy',
#  'Windy and Mostly Cloudy',
#  'Windy and Overcast',
#  'Windy and Partly Cloudy']

# %% [markdown]
# в соответствии каждому наименованию запишем числовую характеристику

# %%
s_v = {
 'Breezy': 1.0,
 'Breezy and Dry': 1.2,
 'Breezy and Foggy': 1.4,
 'Breezy and Mostly Cloudy': 1.6,
 'Breezy and Overcast': 1.8,
 'Breezy and Partly Cloudy': 2,
 'Clear': 3,
 'Dangerously Windy and Partly Cloudy': 4,
 'Drizzle': 5,
 'Dry': 6.3,
 'Dry and Mostly Cloudy': 6.6,
 'Dry and Partly Cloudy': 6.9,
 'Foggy': 8,
 'Humid and Mostly Cloudy': 9.3,
 'Humid and Overcast': 9.6,
 'Humid and Partly Cloudy': 9.9,
 'Light Rain': 11,
 'Mostly Cloudy': 12,
 'Overcast': 13,
 'Partly Cloudy': 14,
 'Rain': 15,
 'Windy': 16,
 'Windy and Dry': 16.2,
 'Windy and Foggy': 16.4,
 'Windy and Mostly Cloudy': 16.6,
 'Windy and Overcast': 16.8,
 'Windy and Partly Cloudy': 17
}

# %% [markdown]
# Создаем новый столбец с числовыми значениями

# %%
df['Summary_Nums'] = [s_v[i] for i in df['Summary']]

# %%
df.head()
# Out:
#                                      Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#                                Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200                  7.388889      0.89
# 2006-04-01 01:00:00.000 +0200                  7.227778      0.86
# 2006-04-01 02:00:00.000 +0200                  9.377778      0.89
# 2006-04-01 03:00:00.000 +0200                  5.944444      0.83
# 2006-04-01 04:00:00.000 +0200                  6.977778      0.83
#
#                                Wind Speed (km/h)  Wind Bearing (degrees)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200            14.1197                   251.0
# 2006-04-01 01:00:00.000 +0200            14.2646                   259.0
# 2006-04-01 02:00:00.000 +0200             3.9284                   204.0
# 2006-04-01 03:00:00.000 +0200            14.1036                   269.0
# 2006-04-01 04:00:00.000 +0200            11.0446                   259.0
#
#                                Visibility (km)  Loud Cover  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200          15.8263         0.0
# 2006-04-01 01:00:00.000 +0200          15.8263         0.0
# 2006-04-01 02:00:00.000 +0200          14.9569         0.0
# 2006-04-01 03:00:00.000 +0200          15.8263         0.0
# 2006-04-01 04:00:00.000 +0200          15.8263         0.0
#
#                                Pressure (millibars)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200               1015.13
# 2006-04-01 01:00:00.000 +0200               1015.63
# 2006-04-01 02:00:00.000 +0200               1015.94
# 2006-04-01 03:00:00.000 +0200               1016.41
# 2006-04-01 04:00:00.000 +0200               1016.51
#
#                                                    Daily Summary  Summary_Nums
# Formatted Date
# 2006-04-01 00:00:00.000 +0200  Partly cloudy throughout the day.          14.0
# 2006-04-01 01:00:00.000 +0200  Partly cloudy throughout the day.          14.0
# 2006-04-01 02:00:00.000 +0200  Partly cloudy throughout the day.          12.0
# 2006-04-01 03:00:00.000 +0200  Partly cloudy throughout the day.          14.0
# 2006-04-01 04:00:00.000 +0200  Partly cloudy throughout the day.          12.0

# %% [markdown]
# Аналогичная процедура со столбцом Осадки

# %%
precip_type = []
for i in df['Precip Type']:
    if not i in precip_type:
        precip_type.append(i)
precip_type
# Out:
# ['rain', 'snow', nan]

# %%
p_t = {
    'rain': 1,
    'snow': 2,
    np.nan: 0
}

# %%
df['Precip Type_Nums'] = [p_t[i] for i in df['Precip Type']]

# %%
df.head()
# Out:
#                                      Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#                                Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200                  7.388889      0.89
# 2006-04-01 01:00:00.000 +0200                  7.227778      0.86
# 2006-04-01 02:00:00.000 +0200                  9.377778      0.89
# 2006-04-01 03:00:00.000 +0200                  5.944444      0.83
# 2006-04-01 04:00:00.000 +0200                  6.977778      0.83
#
#                                Wind Speed (km/h)  Wind Bearing (degrees)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200            14.1197                   251.0
# 2006-04-01 01:00:00.000 +0200            14.2646                   259.0
# 2006-04-01 02:00:00.000 +0200             3.9284                   204.0
# 2006-04-01 03:00:00.000 +0200            14.1036                   269.0
# 2006-04-01 04:00:00.000 +0200            11.0446                   259.0
#
#                                Visibility (km)  Loud Cover  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200          15.8263         0.0
# 2006-04-01 01:00:00.000 +0200          15.8263         0.0
# 2006-04-01 02:00:00.000 +0200          14.9569         0.0
# 2006-04-01 03:00:00.000 +0200          15.8263         0.0
# 2006-04-01 04:00:00.000 +0200          15.8263         0.0
#
#                                Pressure (millibars)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200               1015.13
# 2006-04-01 01:00:00.000 +0200               1015.63
# 2006-04-01 02:00:00.000 +0200               1015.94
# 2006-04-01 03:00:00.000 +0200               1016.41
# 2006-04-01 04:00:00.000 +0200               1016.51
#
#                                                    Daily Summary  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200  Partly cloudy throughout the day.
# 2006-04-01 01:00:00.000 +0200  Partly cloudy throughout the day.
# 2006-04-01 02:00:00.000 +0200  Partly cloudy throughout the day.
# 2006-04-01 03:00:00.000 +0200  Partly cloudy throughout the day.
# 2006-04-01 04:00:00.000 +0200  Partly cloudy throughout the day.
#
#                                Summary_Nums  Precip Type_Nums
# Formatted Date
# 2006-04-01 00:00:00.000 +0200          14.0                 1
# 2006-04-01 01:00:00.000 +0200          14.0                 1
# 2006-04-01 02:00:00.000 +0200          12.0                 1
# 2006-04-01 03:00:00.000 +0200          14.0                 1
# 2006-04-01 04:00:00.000 +0200          12.0                 1

# %% [markdown]
# Удаляем ненужные столбцы

# %%
final_data = df.drop(['Daily Summary', 'Summary', 'Precip Type'], axis=1)

# %%
final_data.head()
# Out:
#                                Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200         9.472222                  7.388889
# 2006-04-01 01:00:00.000 +0200         9.355556                  7.227778
# 2006-04-01 02:00:00.000 +0200         9.377778                  9.377778
# 2006-04-01 03:00:00.000 +0200         8.288889                  5.944444
# 2006-04-01 04:00:00.000 +0200         8.755556                  6.977778
#
#                                Humidity  Wind Speed (km/h)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200      0.89            14.1197
# 2006-04-01 01:00:00.000 +0200      0.86            14.2646
# 2006-04-01 02:00:00.000 +0200      0.89             3.9284
# 2006-04-01 03:00:00.000 +0200      0.83            14.1036
# 2006-04-01 04:00:00.000 +0200      0.83            11.0446
#
#                                Wind Bearing (degrees)  Visibility (km)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200                   251.0          15.8263
# 2006-04-01 01:00:00.000 +0200                   259.0          15.8263
# 2006-04-01 02:00:00.000 +0200                   204.0          14.9569
# 2006-04-01 03:00:00.000 +0200                   269.0          15.8263
# 2006-04-01 04:00:00.000 +0200                   259.0          15.8263
#
#                                Loud Cover  Pressure (millibars)  Summary_Nums  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200         0.0               1015.13          14.0
# 2006-04-01 01:00:00.000 +0200         0.0               1015.63          14.0
# 2006-04-01 02:00:00.000 +0200         0.0               1015.94          12.0
# 2006-04-01 03:00:00.000 +0200         0.0               1016.41          14.0
# 2006-04-01 04:00:00.000 +0200         0.0               1016.51          12.0
#
#                                Precip Type_Nums
# Formatted Date
# 2006-04-01 00:00:00.000 +0200                 1
# 2006-04-01 01:00:00.000 +0200                 1
# 2006-04-01 02:00:00.000 +0200                 1
# 2006-04-01 03:00:00.000 +0200                 1
# 2006-04-01 04:00:00.000 +0200                 1

# %% [markdown]
# # Построение классической регрессии (линейная регрессия)

# %%
from sklearn.linear_model import LinearRegression

# %%
X = final_data.drop(['Apparent Temperature (C)'], axis=1).values
y = final_data['Apparent Temperature (C)'].values

# %%
kFold = KFold(n_splits = 10, random_state = 7, shuffle = True)
model = LinearRegression() #экземпляр класса

# %%
# метод, которым будет оценен результат (среднеквадратичная ошибка)
scoring = 'neg_mean_squared_error'

# применим кросс-валидацию
results = cross_val_score(model, X, y, cv = kFold, scoring = scoring)
print('Среднеквадратичная ошибка: ',results.mean())
# Out:
# Среднеквадратичная ошибка:  -1.1482364925487931

# %% [markdown]
# # Регрессия с резуляризацией (резуляризация - переобучаемость модели)

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge()

# применим кросс-валидацию
results = cross_val_score(model, X, y, cv = kFold, scoring = scoring)
print('Среднеквадратичная ошибка: ',results.mean())
# Out:
# Среднеквадратичная ошибка:  -1.1482364775066454

# %% [markdown]
# ## Lasso Regression (L1-регуляризация: удаление незначимых признаков)

# %%
from sklearn.linear_model import Lasso

# %%
model = Lasso()

# применим кросс-валидацию
results = cross_val_score(model, X, y, cv = kFold, scoring = scoring)
print('Среднеквадратичная ошибка: ',results.mean())
# Out:
# Среднеквадратичная ошибка:  -1.217223198739984

# %% [markdown]
# ## Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet

# %%
model = ElasticNet()

# применим кросс-валидацию
results = cross_val_score(model, X, y, cv = kFold, scoring = scoring)
print('Среднеквадратичная ошибка: ',results.mean())
# Out:
# Среднеквадратичная ошибка:  -1.2031668573399943
